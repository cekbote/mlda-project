# %% [markdown]
# <a href="https://colab.research.google.com/github/cekbote/mlda-project/blob/master/MLDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning and Data Analysis Project

# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader.data import DataReader
from datetime import datetime

# %%
# Customising the plots
sns.set_style('whitegrid')
plt.style.use("seaborn-notebook")
# %matplotlib inline

# %% [markdown]
# ## Analysis of the Stock Price over Time

# %%
# The tech stocks that would be used for this analysis.
stock_list = {'AAPL':[], 'GOOG':[], 'MSFT':[], 'AMZN':[]}

# Choosing the start and end times for getting the stocks for the past year.
end_time = datetime.now()
start_time = datetime(end_time.year - 1, end_time.month, end_time.day)

# Getting the stocks via the Yahoo Fianance Dataset.
for stock in stock_list.keys():   
    stock_list[stock] = DataReader(stock, 'yahoo', start_time, end_time)

# Creating a list of the company names. 
company_name = ["Apple", "Google", "Microsoft", "Amazon"]

# Populating the dataframe with the company names.
for stock, name in zip(stock_list.keys(), company_name):
    stock_list[stock]["Name"] = name

# Creating a new array.
arr = [];

for stock in stock_list.keys():
    arr.append(stock_list[stock])

# Concating all the DataFrames.
df = pd.concat(arr, axis=0)

# Displaying the DataFrame.
df.tail(5)
# Out:
#                    High          Low  ...    Adj Close    Name
# Date                                  ...
# 2020-09-21  2962.000000  2871.000000  ...  2960.469971  Amazon
# 2020-09-22  3133.989990  3000.199951  ...  3128.989990  Amazon
# 2020-09-23  3127.000000  2992.379883  ...  2999.860107  Amazon
# 2020-09-24  3069.300049  2965.000000  ...  3019.790039  Amazon
# 2020-09-25  3101.540039  2999.000000  ...  3095.129883  Amazon
#
# [5 rows x 7 columns]

# %%
# General Info Regarding the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1008 entries, 2019-09-27 to 2020-09-25
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1008 non-null   float64
#  1   Low        1008 non-null   float64
#  2   Open       1008 non-null   float64
#  3   Close      1008 non-null   float64
#  4   Volume     1008 non-null   float64
#  5   Adj Close  1008 non-null   float64
#  6   Name       1008 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 63.0+ KB

# %%
# Describing the DataFrame

for stock in stock_list.keys(): 
    print(stock_list[stock]['Name'][0])  
    print(stock_list[stock].describe())
    print('___________________________________')
    print()
# Out:
# Apple
#              High         Low        Open       Close        Volume   Adj Close
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02  252.000000
# mean    81.596399   79.387569   80.457540   80.586934  1.357588e+08   80.279763
# std     19.147927   18.269755   18.900762   18.692116  5.565670e+07   18.843405
# min     55.240002   53.152500   54.607498   54.705002  4.661760e+07   54.167561
# 25%     66.998751   65.669376   66.344378   66.536253  9.675850e+07   66.131266
# 50%     77.517502   75.523750   76.101250   77.046249  1.255824e+08   76.741184
# 75%     91.581251   89.451876   90.990627   91.027496  1.654629e+08   90.863670
# max    137.979996  130.529999  137.589996  134.179993  3.743368e+08  134.179993
# ___________________________________
#
# Google
#               High          Low  ...        Volume    Adj Close
# count   252.000000   252.000000  ...  2.520000e+02   252.000000
# mean   1393.815747  1361.837783  ...  1.793589e+06  1378.748668
# std     130.271484   131.297204  ...  7.731625e+05   130.491618
# min    1071.319946  1013.536011  ...  3.475000e+05  1056.619995
# 25%    1297.883301  1272.212524  ...  1.309200e+06  1291.027496
# 50%    1406.570007  1374.127502  ...  1.579650e+06  1388.779968
# 75%    1492.761230  1465.347504  ...  1.992325e+06  1480.337463
# max    1733.180054  1666.329956  ...  4.267700e+06  1728.280029
#
# [8 rows x 6 columns]
# ___________________________________
#
# Microsoft
#              High         Low        Open       Close        Volume   Adj Close
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02  252.000000
# mean   177.182818  172.756190  174.990278  175.102103  3.599314e+07  174.216409
# std     25.823451   25.113555   25.562325   25.541282  1.787449e+07   25.941300
# min    136.369995  132.520004  134.949997  134.649994  8.989200e+06  133.134323
# 25%    154.750000  150.659996  151.724998  152.090000  2.348362e+07  151.045975
# 50%    174.699997  170.555000  173.650002  173.154999  3.123190e+07  172.257690
# 75%    202.747505  196.282501  198.874996  200.435001  4.224920e+07  200.162251
# max    232.860001  227.350006  229.270004  231.649994  9.707360e+07  231.649994
# ___________________________________
#
# Amazon
#               High          Low  ...        Volume    Adj Close
# count   252.000000   252.000000  ...  2.520000e+02   252.000000
# mean   2335.202698  2274.665554  ...  4.553413e+06  2306.670278
# std     566.667039   540.746409  ...  2.128905e+06   553.422203
# min    1725.000000  1626.030029  ...  8.813000e+05  1676.609985
# 25%    1822.140015  1788.329956  ...  3.016575e+06  1801.482483
# 50%    2117.065063  2038.049988  ...  3.985050e+06  2087.625000
# 75%    2782.705078  2713.614929  ...  5.635700e+06  2755.640076
# max    3552.250000  3486.689941  ...  1.556730e+07  3531.449951
#
# [8 rows x 6 columns]
# ___________________________________

# %%
# Plotting the daily High Price

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['High'])
  plt.xlabel('Time')
  plt.ylabel('High Prices')
  plt.title(stock_list[stock]['Name'][0])

# %%
# Plotting the daily Low Price

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Low'])
  plt.xlabel('Time')
  plt.ylabel('Low Prices')
  plt.title(stock_list[stock]['Name'][0])

# %%
# Plotting the daily Opening Price

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Open'])
  plt.xlabel('Time')
  plt.ylabel('Opening Prices')
  plt.title(stock_list[stock]['Name'][0])

# %%
# Plotting the daily Closing Price

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Close'])
  plt.xlabel('Time')
  plt.ylabel('Closing Prices')
  plt.title(stock_list[stock]['Name'][0])

# %%
# Plotting the daily Volume traded
plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Volume'])
  plt.xlabel('Time')
  plt.ylabel('Volume')
  plt.title(stock_list[stock]['Name'][0])

# %%
# Plotting the Adjoint Closing Prices

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Adj Close'])
  plt.xlabel('Time')
  plt.ylabel('Adjoint Closing Prices')
  plt.title(stock_list[stock]['Name'][0])

# %%
# Plotting the Adjoint Closing Prices

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Adj Close'])
  plt.xlabel('Time')
  plt.ylabel('Adjusted Closing Prices')
  plt.title(stock_list[stock]['Name'][0])

# %% [markdown]
# ## Obtaining the Moving Average of the Adoint Closing Price of the Stock

# %%
# Calculating the Moving Average

moving_average = [5, 20, 40]

for stock in stock_list.keys():
  for i in moving_average:
    name = 'MA ' +str(i)
    stock_list[stock][name] = stock_list[stock]['Adj Close'].rolling(i).mean()

# Updated List
stock_list['MSFT'].describe()
# Out:
#              High         Low        Open  ...        MA 5       MA 20       MA 40
# count  252.000000  252.000000  252.000000  ...  248.000000  233.000000  213.000000
# mean   177.182818  172.756190  174.990278  ...  174.275744  174.472936  174.227151
# std     25.823451   25.113555   25.562325  ...   25.558212   24.180875   21.559242
# min    136.369995  132.520004  134.949997  ...  134.832986  136.609760  140.535263
# 25%    154.750000  150.659996  151.724998  ...  151.733599  152.788113  158.312913
# 50%    174.699997  170.555000  173.650002  ...  172.416864  172.602000  168.861625
# 75%    202.747505  196.282501  198.874996  ...  198.837844  196.416699  193.232590
# max    232.860001  227.350006  229.270004  ...  227.988000  216.004071  211.609239
#
# [8 rows x 9 columns]

# %%
# Plotting the Moving Average 

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Adj Close'], 
           label='Adjusted Closing Price')
  plt.plot(stock_list[stock]['MA 5'], label='Moving Average (5 Days)')
  plt.plot(stock_list[stock]['MA 20'], label='Moving Average (20 Days)')
  plt.plot(stock_list[stock]['MA 40'], label='Moving Average (40 Days)')
  plt.legend(loc="upper left")
  plt.xlabel('Time')
  plt.ylabel('Adjusted Closing Prices')
  plt.title(stock_list[stock]['Name'][0])

# %% [markdown]
# ## Percentage Change in the Daily Adjusted Closing Price

# %%
# Obataining the Daily Percentage Change

for stock in stock_list.keys():
  stock_list[stock]['Percentage Change'] = stock_list[stock]['Adj Close'].pct_change()

# %%
# Plotting the Daily Percentage Change

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  plt.plot(stock_list[stock]['Percentage Change'])
  plt.xlabel('Time')
  plt.ylabel('Percentage Change')
  plt.title(stock_list[stock]['Name'][0])

# %%
# Plotting the Percentage Change Distribution

plt.figure(figsize=(20,10))
for stock, i in zip(stock_list.keys(), range(4)):
  plt.subplot(2,2, i+1)
  sns.distplot(stock_list[stock]['Percentage Change'], hist=True, kde=True)
  plt.xlabel('Time')
  plt.ylabel('Percentage Change')
  plt.title(stock_list[stock]['Name'][0])

# %% [markdown]
# ## Obtaining the Correlation between the Adjusted Closing Prices of Different Stocks

# %%
# Creating a new DataFrame that has all the Adjusted Closing Prices

cldf = pd.DataFrame()

for stock in stock_list.keys():
    cldf[stock_list[stock]['Name'][0]] = stock_list[stock]['Adj Close']

cldf.head(5)
# Out:
#                 Apple       Google   Microsoft       Amazon
# Date
# 2019-09-27  54.167561  1225.089966  136.179642  1725.449951
# 2019-09-30  55.442406  1219.000000  137.465027  1735.910034
# 2019-10-01  55.595886  1205.099976  135.527100  1735.650024
# 2019-10-02  54.202213  1176.630005  133.134323  1713.229980
# 2019-10-03  54.662643  1187.829956  134.745972  1724.420044

# %%
# Getting the correlation between different stocks as a scatter plot

sns.pairplot(cldf, kind='reg')

# %%
# Getting the correlation between different stocks as a distribution
pair_plot = sns.PairGrid(cldf.dropna())
pair_plot.map_upper(sns.kdeplot)
pair_plot.map_diag(plt.hist, bins = 20)
pair_plot.map_lower(sns.kdeplot)

# %%
# Plotting a Correlation Matrix

cor = cldf.corr()
sns.heatmap(cor, annot=True, cmap='Blues')
